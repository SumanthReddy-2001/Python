# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

# %%
fle_path = "/Volumes/workspace/default/kaggle_datasets/employee_salary_dataset.csv"
emp_df = spark.read.format("csv").option("header", "true").option("inferSchema", "true").load(fle_path)
display(emp_df)

# %%
output_file_path = "/Volumes/workspace/default/kaggle_datasets/employee_data"
emp_df.write.format("parquet").mode("overwrite").save(output_file_path)

# %%
output_file_path ="/Volumes/workspace/default/kaggle_datasets/employee_data"
emp_df.write.format("delta").mode("overwrite").saveAsTable("employee_data")
display(spark.sql("DESCRIBE DETAIL employee_data"))
